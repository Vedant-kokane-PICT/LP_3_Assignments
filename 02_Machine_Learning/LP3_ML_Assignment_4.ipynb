# %% [markdown]
# *   Name - Vedant Kokane
# *   Class - BE 4
# *   Roll no - 41429
#
# Implement Gradient Descent Algorithm to find the local minima of a function. For example, find the local minima of the function y=(x+3)2 starting from the point x=2
#
# find the local minima of the function y=(x+3)² starting from the point x=2
#
# *  Equation = (x+3)^2
# *   We need to find the local Minima using gradient descent

# %%
# intial values
current_x = 2
learning_rate = 0.01
precision = 0.000001  # it is also called tolerance
max_iterations = 10000

# %%
# slope will be the derivative of the equation using chain rule
# slope = 2 * (x + 3) (derivative using chain rule (dy/dx))
def slope(x):
  return 2 * (x + 3)

def y(x):
  return (x+3) ** 2

# %%
y_values = []
x_values = []
x_values.append(current_x)
y_values.append(y(current_x))

# %%
# In gradientdescent  new_x = old_x - (learning_rate * slope)

def gradient_descent(current_x, learning_rate, precision, max_iterations, x_values, y_values):
  iteration_count = 1
  while iteration_count <= max_iterations:
    previous_x = current_x
    current_x = current_x - (learning_rate * slope(current_x))
    x_values.append(current_x)
    y_values.append(y(current_x))
    if abs(current_x - previous_x) < precision:
      break

    print(f"Iteration - {iteration_count}" )
    print(f"X = {current_x}")
    iteration_count = iteration_count + 1

# %%
gradient_descent(current_x,learning_rate,precision,max_iterations,x_values,y_values)
# Out:
# Iteration - 1
# X = 1.9
# Iteration - 2
# X = 1.8019999999999998
# Iteration - 3
# X = 1.70596
# Iteration - 4
# X = 1.6118408
# Iteration - 5
# X = 1.519603984
# Iteration - 6
# X = 1.42921190432
# Iteration - 7
# X = 1.3406276662336
# Iteration - 8
# X = 1.253815112908928
# Iteration - 9
# X = 1.1687388106507495
# Iteration - 10
# X = 1.0853640344377344
# Iteration - 11
# X = 1.0036567537489798
# Iteration - 12
# X = 0.9235836186740002
# Iteration - 13
# X = 0.8451119463005202
# Iteration - 14
# X = 0.7682097073745098
# Iteration - 15
# X = 0.6928455132270196
# Iteration - 16
# X = 0.6189886029624792
# Iteration - 17
# X = 0.5466088309032295
# Iteration - 18
# X = 0.4756766542851649
# Iteration - 19
# X = 0.40616312119946163
# Iteration - 20
# X = 0.3380398587754724
# Iteration - 21
# X = 0.27127906159996296
# Iteration - 22
# X = 0.2058534803679637
# Iteration - 23
# X = 0.14173641076060442
# Iteration - 24
# X = 0.07890168254539233
# Iteration - 25
# X = 0.017323648894484484
# ...

# %%
# plotting the values of x and y on graph
import matplotlib.pyplot as plt
plt.scatter(x_values,y_values)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gradient Descent for equation - y=(x+3)^2')
plt.show()
